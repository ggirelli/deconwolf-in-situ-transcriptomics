# %%
require(cowplot)
require(data.table)
require(ggplot2)
require(ggpubr)
require(pbapply)
pboptions(type="timer")
# Out:
# Loading required package: cowplot
#
#
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
# Loading required package: data.table
#
# Loading required package: ggplot2
#
# Loading required package: ggpubr
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
# Loading required package: pbapply

# %%
nthreads=10

# %%
empty_plot = ggplot()

# %% [markdown]
# # Figure 4

# %%
plist = list(
    A=readRDS("panels_rds/fig_4a.rds"),
    B=readRDS("panels_rds/fig_4b.rds"),
    C=readRDS("panels_rds/fig_4c.rds"),
    D=readRDS("panels_rds/fig_4d.rds")
)

# %%
options(repr.plot.width=12, repr.plot.height=12)
p = plot_grid(plotlist=plist[1:4], nrow=2, align="hv", axis="blt", labels=letters[1:4])
p
# Out:
# Warning message:
# “Removed 10 rows containing missing values (geom_point).”
# Warning message:
# “Removed 10 rows containing missing values (geom_point).”
# plot without title

# %%
ggsave(plot=p, file="figures/fig_4.png", width=10, height=15, bg="white")
ggsave(plot=p, file="figures/fig_4.jpg", width=10, height=15, bg="white")

# %% [markdown]
# # Figure X4

# %%
plist = list(
    A=readRDS("panels_rds/supp_fig_x4a.rds")
)

# %%
options(repr.plot.width=6, repr.plot.height=6)
p = plot_grid(plotlist=plist[1], nrow=1, align="hv", axis="blt", labels=letters[1])
p
# Out:
# plot without title

# %%
ggsave(plot=p, file="figures/supp_fig_x4.png", width=10, height=15, bg="white")
ggsave(plot=p, file="figures/supp_fig_x4.jpg", width=10, height=15, bg="white")
